# %%
import pandas as pd
#直接用pandas的dataframe讀取csv檔案
df = pd.read_csv('world.csv')
df.head()
# Out:
#    ID iso_code  洲名   國家          日期  總確診數  新增確診數  七天移動平均新增確診數  總死亡數  新增死亡數  \
# 0   1      AFG  亞洲  阿富汗  2020-02-24     5      5          0.0     0      0
# 1   2      AFG  亞洲  阿富汗  2020-02-25     5      0          0.0     0      0
# 2   3      AFG  亞洲  阿富汗  2020-02-26     5      0          0.0     0      0
# 3   4      AFG  亞洲  阿富汗  2020-02-27     5      0          0.0     0      0
# 4   5      AFG  亞洲  阿富汗  2020-02-28     5      0          0.0     0      0
#
#    ...  七天移動平均疫苗新增接種劑數  每百人接種疫苗劑數  每百人接種疫苗人數  疫情控管指數      總人口數  中位數年紀  \
# 0  ...             0.0        0.0        0.0    8.33  39835428   18.6
# 1  ...             0.0        0.0        0.0    8.33  39835428   18.6
# 2  ...             0.0        0.0        0.0    8.33  39835428   18.6
# 3  ...             0.0        0.0        0.0    8.33  39835428   18.6
# 4  ...             0.0        0.0        0.0    8.33  39835428   18.6
#
#    70歲以上人口比例   平均壽命  解除隔離數     解封指數
# 0      1.337  64.83      0  99999.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187885 entries, 0 to 187884
# Data columns (total 33 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   ID              187885 non-null  int64
#  1   iso_code        187885 non-null  object
#  2   洲名              187885 non-null  object
#  3   國家              187885 non-null  object
#  4   日期              187885 non-null  object
#  5   總確診數            187885 non-null  int64
#  6   新增確診數           187885 non-null  int64
#  7   七天移動平均新增確診數     187885 non-null  float64
#  8   總死亡數            187885 non-null  int64
#  9   新增死亡數           187885 non-null  int64
#  10  七天移動平均新增死亡數     187885 non-null  float64
#  11  每百萬人確診數         187885 non-null  float64
#  12  每百萬人死亡數         187885 non-null  float64
#  13  傳染率             187885 non-null  float64
#  14  新增檢驗件數          187885 non-null  int64
#  15  總檢驗件數           187885 non-null  int64
# ...

# %%
df1 = df[['洲名','國家','日期','總確診數','新增確診數','總人口數','解封指數']]
df1.head()
# Out:
#    洲名   國家          日期  總確診數  新增確診數      總人口數     解封指數
# 0  亞洲  阿富汗  2020-02-24     5      5  39835428  99999.0
# 1  亞洲  阿富汗  2020-02-25     5      0  39835428  99999.0
# 2  亞洲  阿富汗  2020-02-26     5      0  39835428  99999.0
# 3  亞洲  阿富汗  2020-02-27     5      0  39835428  99999.0
# 4  亞洲  阿富汗  2020-02-28     5      0  39835428  99999.0

# %%
df1.iloc[187884]
# Out:
# 洲名               非洲
# 國家              辛巴威
# 日期       2022-07-06
# 總確診數         255805
# 新增確診數            50
# 總人口數       15092171
# 解封指數        99999.0
# Name: 187884, dtype: object

# %%
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
        'Age': [25, 30, 22, 35, 28],
        'City': ['NewYork', 'London', 'Paris', 'Tokyo', 'NewYork'],
        'Score': [90, 85, 95, 78, 92]}

df_test = pd.DataFrame(data)
df_test
# Out:
#       Name  Age     City  Score
# 0    Alice   25  NewYork     90
# 1      Bob   30   London     85
# 2  Charlie   22    Paris     95
# 3    David   35    Tokyo     78
# 4      Eva   28  NewYork     92

# %%
#布林遮照
mask = df_test['Score'] >= 90
mask
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# Name: Score, dtype: bool

# %%
df_test[mask]
# Out:
#       Name  Age     City  Score
# 0    Alice   25  NewYork     90
# 2  Charlie   22    Paris     95
# 4      Eva   28  NewYork     92

# %%
country_mask = df1['國家'] == '日本'
df1[country_mask]
# Out:
# <class 'pandas.core.series.Series'>
#        洲名  國家          日期     總確診數  新增確診數       總人口數     解封指數
# 85626  亞洲  日本  2020-01-22        2      0  126050796  99999.0
# 85627  亞洲  日本  2020-01-23        2      0  126050796  99999.0
# 85628  亞洲  日本  2020-01-24        2      0  126050796  99999.0
# 85629  亞洲  日本  2020-01-25        2      0  126050796  99999.0
# 85630  亞洲  日本  2020-01-26        4      2  126050796  99999.0
# ...    ..  ..         ...      ...    ...        ...      ...
# 86518  亞洲  日本  2022-07-02  9364954  24875  126050796  99999.0
# 86519  亞洲  日本  2022-07-03  9388222  23268  126050796  99999.0
# 86520  亞洲  日本  2022-07-04  9405007  16785  126050796  99999.0
# 86521  亞洲  日本  2022-07-05  9441171  36164  126050796  99999.0
# 86522  亞洲  日本  2022-07-06  9486965  45794  126050796  99999.0
#
# [897 rows x 7 columns]

# %%
#布林遮罩連續篩選搜尋資料用法
taiwan_mask = (df1['國家'] == '台灣') & (df1['新增確診數'] >= 100000)
df1[taiwan_mask]
# Out:
#         洲名  國家          日期    總確診數   新增確診數      總人口數   解封指數
# 164830  亞洲  台灣  2022-05-09  397504  128935  23855008  25.86
# 164835  亞洲  台灣  2022-05-14  699824  128954  23855008  46.24

# %%
#也可以用query搜尋資料，達到與上面一樣效果
df1.query('國家=="台灣" and 新增確診數>=100000')
# Out:
#         洲名  國家          日期    總確診數   新增確診數      總人口數   解封指數
# 164830  亞洲  台灣  2022-05-09  397504  128935  23855008  25.86
# 164835  亞洲  台灣  2022-05-14  699824  128954  23855008  46.24

# %%
#安裝matplotlib.pyplt模組
import matplotlib.pyplot as plt
#安裝matplotlib.font_manager模組中的fontManager實體並匯入
from matplotlib.font_manager import fontManager
import matplotlib as mlp
#使用fontManager的實體方法addfont，將ChineseFont.ttf匯入到matplotlib
fontManager.addfont('ChineseFont.ttf')
#使用matplotlib模組中的rc函數，將ChineseFont.ttf作為matplotlib的預設字型，此時就可以打中文了
mlp.rc('font', family='ChineseFont')

# %%
figure = plt.figure(figsize=(10,6))
axes = figure.add_subplot(1,1,1)
axes.set_xticks([1, 3, 5, 7, 9])
axes.set_yticks([-1, -0.5, 0, 0.5, 1])
plt.show()

# %%
figure = plt.figure(figsize=(10,6))
axes = figure.add_subplot(1,1,1)
axes.plot([11, 3, 5, 7, 9],marker='o',color='red', linestyle='')
plt.show()

# %%
figure = plt.figure(figsize=(10,6))
ax1 = figure.add_subplot(2,1,1)
ax1.plot([11, 3, 5, 7, 9],marker='o',color='red', linestyle='')
ax2 = figure.add_subplot(2,1,2)
ax2.bar(['a', 'b', 'c', 'd', 'e'],[1, 2, 3, 4, 5])
plt.show()

# %%
student1 = {'國文':78, '英文':80, '數學':92, '歷史':75, '探索':85}
student2 = {'國文':90, '英文':75, '數學':98, '歷史':65, '探索':75}

# %%
subjects = list(student1.keys())
score1 = list(student1.values())
score2 = list(student2.values())
figure = plt.figure(figsize=(10,8))
axes = figure.add_subplot(1,1,1)
axes.set_title("小明與大雄成績表")
axes.set_xlabel("科目")
axes.set_ylabel("分數")
axes.plot(subjects,score1,'ro-',label="小明")
axes.plot(subjects,score2,'gx-.',label="大雄")
axes.legend()
axes.grid(axis='y')

# 找出數學在subjects列表中的索引
math_index = subjects.index('數學')

for idx, (s, v1, v2) in enumerate(zip(subjects, score1, score2)):
    if s == '數學' and v1 == 92:
        # 對於數學成績，使用特殊的箭頭樣式
        # 使用arc3連接樣式並調整弧度來模擬90度轉向
        axes.annotate(f'{v1}分退步了', 
                      xy=(math_index, v1), 
                      xytext=(math_index+1, v1-5),  # 將文字向右上方移動
                      arrowprops=dict(
                          facecolor='red',
                          shrink=0.05,
                          connectionstyle='arc3,rad=-0.3'  # 負值使弧度向右彎曲
                      ))
        axes.annotate(f'{v2}', xy=(s, v2+0.5))
    else:
        axes.annotate(f'{v1}', xy=(s, v1+0.5))
        axes.annotate(f'{v2}', xy=(s, v2+0.5))
plt.show()

# %%
#快速畫法
import numpy as np 
#使用numpy中的pi屬性(也就是圓周率)
x = np.arange(-2*np.pi, 2*np.pi, 0.01)
y1 = np.sin(3*x) / x
y2 = np.sin(2*x) / x
y3 = np.sin(1*x) / x

plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x, y3)
